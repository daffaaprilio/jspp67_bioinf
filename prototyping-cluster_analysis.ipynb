# %%
import pickle
import pandas as pd
from pathlib import Path
import networkx as nx
import py4cytoscape as p4c

# %%
def coexdir_to_edgeslist(coex_dir):
    '''
    create a function that opens an ATTED-II style gene coexpression directory,
    read all the contents temporarily through a python dataframe,
    filter only necessary edges (important to slim down the edge-list size)
    store the final content as an edge-list
    u-v has z weight: gene u and gene v is co-expressed with a value of z (z-score)
    '''
    edges = []

    for file in coex_dir.glob('*'):
        u = str(file.stem)
        # temporary df, rewritten every iteration of for loop
        df = pd.read_csv(file, sep='\t', header=None, names=['v', 'z'])
        df['v'] = df['v'].astype(str)

        # from each file, filter top K coexpressed genes & with a certain min Z score
        df = df.nlargest(K, 'z')
        df = df[df['z'] >= minZ]    

        # store to a list
        for v, z in zip(df['v'], df['z']):
            edges.append((u, v, float(z)))
    
    return edges

def build_graph(edges):
    '''
    initiate an empty undirected graph, then load the edges list
    use the correct method (add_weighted_edges_from)
    '''
    G = nx.Graph()
    # G.add_weighted_edges_from(edges)
    for u, v, z, in edges:
        if G.has_edge(u, v):
            if z > G[u][v]['weight']:
                G[u][v]['weight'] = z
        else:
            G.add_edge(u, v, weight=z)

    return G

def save_object(pyobj, pklobj):
    with open(pklobj, 'wb') as f:
        pickle.dump(pyobj, f)
    
    return None

def _main(coex_dir, output_dirname):
    edges = coexdir_to_edgeslist(coex_dir)
    G = build_graph(edges)

    # output_path = Path(output_dirname)
    # output_path.mkdir(parents=True, exist_ok=True)

    # save_object(G, output_path / 'sbi_G_prpF.pkl')
    # save_object(edges, output_path / 'sbi_edges.pkl')

sbi_coex_dir = Path('data/reference/sbi_coex')
K = 10
minZ = float(4)

# %%
if __name__ == '__main__':
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    default_output = Path(f'TAA_cluster-1st_attempt/{timestamp}')

    parser = argparse.ArgumentParser(description='Create coexpression network')
    parser.add_argument('--coex-dir', '-c', type=Path, default=sbi_coex_dir,
                        help='Path to ATTED-II style coexpression directory')
    parser.add_argument('--output-dir', '-o', type=Path, default=default_output,
                        help=f'Output directory for graph and edges pickle (default folder name is {default_output})')
    parser.add_argument('--gene-no', '-k', type=int, default=10,
                        help='From each file in the coex dir, filter up to K number of genes to be included in the network')
    parser.add_argument('--z-score', '-z', type=float, default=4,
                        help='From each file in the coex dir, filter only genes coexpressed with min z score')
    args = parser.parse_args()

    _main(args.coex_dir, args.output_dir)
    # _main(sbi_coex_dir, output_dir)

# %% [markdown]
# ## preparing ready-to-search geneid from 01

# %%
RESULTS = Path("results/gene_network")

# %%
files = sorted(RESULTS.glob("map*-K*_kegg/map*-K*_kegg-01-homologous_geneID.txt"))

top_hits = []
for f in files:
    df = pd.read_csv(f, sep='\t')
    if df.empty:
        continue
    top = df.iloc[[0]].copy()
    # extract the KO tag from the parent folder name, e.g. "map00020-K00234_kegg"
    top.insert(0, "query", f.parent.name.replace("_kegg", ""))
    top_hits.append(top)

top_hits_df = pd.concat(top_hits, ignore_index=True)
top_hits_df
# Out:
#               query protein_accession    gene_id         evalue  \
# 0   map00020-K00025    XP_002467079.1    8070482  1.400000e-213
# 1   map00020-K00026    XP_002443645.2    8065238  1.100000e-190
# 2   map00020-K00030    XP_002454117.1    8056475  1.600000e-213
# 3   map00020-K00031    XP_021303439.1  110430300  1.500000e-268
# 4   map00020-K00161    XP_002452579.1    8075734  1.100000e-211
# 5   map00020-K00162    XP_021320770.1  110437034  1.600000e-201
# 6   map00020-K00164    XP_002446307.1    8070970   0.000000e+00
# 7   map00020-K00234    XP_021309515.1  110432855   0.000000e+00
# 8   map00020-K00235    XP_021320812.1  110437047  1.100000e-153
# 9   map00020-K00236    XP_002447454.2    8080288   1.100000e-30
# 10  map00020-K00382    XP_021313051.1  110433993  1.100000e-273
# 11  map00020-K00627    XP_002451778.1    8085529  4.100000e-255
# 12  map00020-K00658    XP_021320725.1  110437027  3.700000e-252
# 13  map00020-K01610    XP_021310349.1  110433065   0.000000e+00
# 14  map00020-K01647    XP_002451828.1    8073811  5.000000e-227
# 15  map00020-K01648    XP_002442337.1    8068084  4.500000e-237
# 16  map00020-K01676    XP_002463651.1    8057068   3.200000e-02
# 17  map00020-K01679    XP_021306456.1  110431614  7.800012e-319
# 18  map00020-K01681    XP_002445174.1    8085012   0.000000e+00
# 19  map00020-K01899    XP_002460917.1    8066942  2.100000e-207
# 20  map00020-K01900    XP_002452471.1    8066155  6.400000e-268
# 21  map00020-K01958    XP_002442486.2    8076667   1.300000e-61
# 22  map00020-K25801    XP_002440990.1    8077918   5.600000e-91
# 23  map00020-K28782    XP_002457769.1    8086307  2.100000e-287
# 24  map00660-K00052    XP_002447363.1    8055458  6.400000e-232
# 25  map00660-K01652    XP_021315526.1    8056085   0.000000e+00
# 26  map00660-K01653    XP_002452423.1    8056510  1.400000e-253
# 27  map00660-K01703    XP_002453237.1    8055065   0.000000e+00
# 28  map00660-K01704    XP_002452816.1    8073966  4.400000e-121
#
#                                           description
# 0   malate dehydrogenase, cytoplasmic [Sorghum bic...
# 1   malate dehydrogenase, glyoxysomal [Sorghum bic...
# 2   isocitrate dehydrogenase [NAD] regulatory subu...
# 3   isocitrate dehydrogenase [NADP] [Sorghum bicolor]
# 4   pyruvate dehydrogenase E1 component subunit al...
# 5   pyruvate dehydrogenase E1 component subunit be...
# 6   2-oxoglutarate dehydrogenase, mitochondrial [S...
# 7   succinate dehydrogenase [ubiquinone] flavoprot...
# 8   succinate dehydrogenase [ubiquinone] iron-sulf...
# 9   succinate dehydrogenase subunit 3-1, mitochond...
# 10  dihydrolipoyl dehydrogenase 1, chloroplastic-l...
# 11  dihydrolipoyllysine-residue acetyltransferase ...
# 12  dihydrolipoyllysine-residue succinyltransferas...
# 13  phosphoenolpyruvate carboxykinase (ATP) [Sorgh...
# 14  citrate synthase, glyoxysomal isoform X1 [Sorg...
# 15  ATP-citrate synthase alpha chain protein 3 [So...
# 16      protein LURP-one-related 15 [Sorghum bicolor]
# 17  fumarate hydratase 1, mitochondrial-like [Sorg...
# 18  putative aconitate hydratase, cytoplasmic [Sor...
# 19  succinate--CoA ligase [ADP-forming] subunit al...
# 20  succinate--CoA ligase [ADP-forming] subunit be...
# 21  methylcrotonoyl-CoA carboxylase subunit alpha,...
# 22  succinate dehydrogenase subunit 4, mitochondri...
# 23  dihydrolipoyl dehydrogenase 1, mitochondrial [...
# 24  3-isopropylmalate dehydrogenase 2, chloroplast...
# 25  acetolactate synthase 1, chloroplastic [Sorghu...
# 26  acetolactate synthase small subunit 2, chlorop...
# 27  3-isopropylmalate dehydratase large subunit, c...
# 28  3-isopropylmalate dehydratase small subunit 3 ...
