# %%
from pathlib import Path

with open("results/hmm_homology/tbrB_refseq/tbrB_refseq-07-homologous_geneID.txt", "r") as f:
    test = f.readlines()
    for line in test:
        next(line)

# %%
test
# Out:
# ['protein_accession\tgene_id\tevalue\tdescription\n',
#  'XP_021306173.1\t8067902\t5.5e-07\tWAT1-related protein At4g01440 [Sorghum bicolor]\n',
#  'XP_002448633.1\t8068479\t0.0001\tuncharacterized vacuolar membrane protein YML018C [Sorghum bicolor]\n',
#  'XP_021313348.1\t110434047\t0.0041\tprobable sugar phosphate/phosphate translocator At1g06470 [Sorghum bicolor]\n',
#  'XP_021313349.1\t110434047\t0.0041\tprobable sugar phosphate/phosphate translocator At1g06470 [Sorghum bicolor]\n',
#  'XP_021313350.1\t110434047\t0.0041\tprobable sugar phosphate/phosphate translocator At1g06470 [Sorghum bicolor]\n',
#  'XP_021313352.1\t110434047\t0.0041\tprobable sugar phosphate/phosphate translocator At1g06470 [Sorghum bicolor]\n',
#  'XP_002451343.1\t8066479\t0.0047\tWAT1-related protein At3g30340 isoform X1 [Sorghum bicolor]\n',
#  'XP_002467019.1\t8067103\t0.02\tWAT1-related protein At3g02690, chloroplastic [Sorghum bicolor]\n',
# ...
